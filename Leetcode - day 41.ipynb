# %% [markdown]
# # Path Sum III
#
# Given the root of a binary tree and an integer targetSum, return the number of paths where the sum of the values along the path equals targetSum.
#
# The path does not need to start or end at the root or a leaf, but it must go downwards (i.e., traveling only from parent nodes to child nodes).
#
#
#
# Example 1:
#
# ![image.png](attachment:image.png)
# Input: root = [10,5,-3,3,2,null,11,3,-2,null,1], targetSum = 8
# Output: 3
# Explanation: The paths that sum to 8 are shown.
# Example 2:
#
# Input: root = [5,4,8,11,null,13,4,7,2,null,null,5,1], targetSum = 22
# Output: 3

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    # define a counter for result
    count=0
    def pathSum(self, root, targetSum):
        def dfs(node,path):
            # if node is null, return
            if not node:
                return 
            # append the current node value to path
            path.append(node.val)
            curSum=0
            # calculate the sum of nodevalues from right, if matches with target sum, increase result counter
            for i in range(len(path)-1,-1,-1):
                curSum+=path[i]
                if curSum==targetSum:
                    self.count+=1       
            # run dfs for right and left nodes
            dfs(node.left,path)
            dfs(node.right,path)
            # pop the element while backtracking
            path.pop()
        dfs(root,[])
        return self.count
